# %% [markdown]
# # Boston House Price Prediction
#
# https://www.kaggle.com/c/boston-housing
#
# - CRIM - per capita crime rate by town
# - ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# - INDUS - proportion of non-retail business acres per town.
# - CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# - NOX - nitric oxides concentration (parts per 10 million)
# - RM - average number of rooms per dwelling
# - AGE - proportion of owner-occupied units built prior to 1940
# - DIS - weighted distances to five Boston employment centres
# - RAD - index of accessibility to radial highways
# - TAX - full-value property-tax rate per \$10,000
# - PTRATIO - pupil-teacher ratio by town
# - B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# - LSTAT - percentage lower status of the population
# - MEDV - Median value of owner-occupied homes in $1000's

# %% [markdown]
# ## Load the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -al /content/drive/MyDrive/AdvancedML/boston.csv
# Out:
# -rw------- 1 root root 24128 Oct 19  2021 /content/drive/MyDrive/AdvancedML/boston.csv

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

# %%
boston_df = pd.read_csv('/content/drive/MyDrive/AdvancedML/boston.csv')

# %%
boston_df.head(5)
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       333 non-null    int64
#  1   crim     333 non-null    float64
#  2   zn       333 non-null    float64
#  3   indus    333 non-null    float64
#  4   chas     333 non-null    int64
#  5   nox      333 non-null    float64
#  6   rm       333 non-null    float64
#  7   age      333 non-null    float64
#  8   dis      333 non-null    float64
#  9   rad      333 non-null    int64
#  10  tax      333 non-null    int64
#  11  ptratio  333 non-null    float64
#  12  black    333 non-null    float64
#  13  lstat    333 non-null    float64
#  14  medv     333 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 39.1 KB

# %% [markdown]
# ### Set X and Y Variables

# %%
boston_df.columns
# Out:
# Index(['ID', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad',
#        'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
X = np.array(boston_df[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad',
       'tax', 'ptratio', 'black', 'lstat']])

# %%
Y = np.array(boston_df.medv)

# %%
X.shape
# Out:
# (333, 13)

# %%
Y.shape
# Out:
# (333,)

# %% [markdown]
# ## Split dataset into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
train_X, test_X, train_y, test_y = train_test_split( X, Y, test_size = 0.2)

# %%
train_X.shape
# Out:
# (266, 13)

# %%
test_X.shape
# Out:
# (67, 13)

# %% [markdown]
# ### Normalize data

# %% [markdown]
# All variables need to be normalized to bring them onto one scale. To scale we can use standardization technique, which is subtracting mean and dividing by standard deviation.
#
# The train and test data need to be normalized based on mean and std of training dataset, as the NN parameters will be estimated based on the training dataset.

# %%
## Calculate meand std from the training dataset
mean = train_X.mean(axis=0)
std = train_X.std(axis=0)

## Standardizing the training dataset
train_X -= mean
train_X /= std

## Standardizing the test dataset
test_X -= mean
test_X /= std

# %% [markdown]
# ## Build NN Model
#
# Explain:
#
# 1. NN Architecture
# 2. Layers and Neurons
# 3. Activation Functions
# 4. Loss Function
# 5. Backpropagation
# 6. Gradient Descent and variations of Gradient Descent
#
# ### Model 1:

# %%
import tensorflow as tf
from tensorflow import keras
from keras import models
from keras.layers import Dense, Activation
from keras.optimizers import SGD

# %%
tf.__version__
# Out:
# '2.12.0'

# %%
keras.__version__
# Out:
# '2.12.0'

# %%
model = models.Sequential()

model.add(Dense(64, input_shape=(train_X.shape[1],)))

model.add(Activation('relu'))

model.add(Dense(64))
model.add(Activation('relu'))

model.add(Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 64)                896
#
#  activation_2 (Activation)   (None, 64)                0
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 5,121
# Trainable params: 5,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="sgd", 
              loss='mse', 
              metrics=['mse'])

# %% [markdown]
# **EPOCH** - an ENTIRE dataset is passed forward and backward through the neural network only ONCE.
#
# **BATCH SIZE** - Total number of training examples present in a single batch. The backpropagation algorithms updates the weights after each batch size operation.
#
# Usually the validation metrics are measured at the end of each epoch to measure progress of the learning in the neural network. (If it is underfitting or overfitting)

# %%
EPOCHS = 30
## BATCH_SIZE

# %% [markdown]
# Explain how data would be taken in batches and run multiple epochs.

# %%
# %%time
history = model.fit(
    train_X, 
    train_y,  # prepared data
    epochs=EPOCHS,
    validation_data=(test_X, test_y),
    verbose=1
)
# Out:
# Epoch 1/30
# 9/9 [==============================] - 1s 30ms/step - loss: 697.1342 - mse: 697.1342 - val_loss: 382.2210 - val_mse: 382.2210
# Epoch 2/30
# 9/9 [==============================] - 0s 7ms/step - loss: 2884.8184 - mse: 2884.8184 - val_loss: 69191952.0000 - val_mse: 69191952.0000
# Epoch 3/30
# 9/9 [==============================] - 0s 10ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 4/30
# 9/9 [==============================] - 0s 7ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 5/30
# 9/9 [==============================] - 0s 7ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 6/30
# 9/9 [==============================] - 0s 6ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 7/30
# 9/9 [==============================] - 0s 8ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 8/30
# 9/9 [==============================] - 0s 9ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 9/30
# 9/9 [==============================] - 0s 7ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 10/30
# 9/9 [==============================] - 0s 6ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 11/30
# 9/9 [==============================] - 0s 6ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 12/30
# 9/9 [==============================] - 0s 6ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 13/30
# 9/9 [==============================] - 0s 7ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 14/30
# 9/9 [==============================] - 0s 6ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 15/30
# 9/9 [==============================] - 0s 7ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 16/30
# 9/9 [==============================] - 0s 5ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 17/30
# 9/9 [==============================] - 0s 8ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 18/30
# 9/9 [==============================] - 0s 8ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 19/30
# 9/9 [==============================] - 0s 7ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 20/30
# 9/9 [==============================] - 0s 7ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 21/30
# 9/9 [==============================] - 0s 6ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 22/30
# 9/9 [==============================] - 0s 6ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 23/30
# 9/9 [==============================] - 0s 6ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 24/30
# 9/9 [==============================] - 0s 9ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 25/30
# 9/9 [==============================] - 0s 5ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 26/30
# 9/9 [==============================] - 0s 6ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 27/30
# 9/9 [==============================] - 0s 6ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 28/30
# 9/9 [==============================] - 0s 6ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 29/30
# 9/9 [==============================] - 0s 7ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# Epoch 30/30
# 9/9 [==============================] - 0s 8ms/step - loss: nan - mse: nan - val_loss: nan - val_mse: nan
# CPU times: user 2.61 s, sys: 99.1 ms, total: 2.71 s
# Wall time: 3.3 s

# %%
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'mse', 'val_loss', 'val_mse'])

# %%
def plot_mse(hist):
    plt.plot(hist['mse'])
    plt.plot(hist['val_mse'])
    plt.title('MSE')
    plt.ylabel('mse')
    plt.xlabel('epoch')
    plt.legend(['train', 
                'test'], 
               loc='upper left')
    plt.show()
    
def plot_loss(hist):
    plt.plot(hist['loss'])
    plt.plot(hist['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 
                'test'], 
               loc='upper left')
    plt.show()

# %%
plot_mse(history.history)
plot_loss(history.history)

# %% [markdown]
# The loss is diverging. The leanring rate is high.
#
# - Explain learning Rate

# %% [markdown]
# ### Model 2: With Lower Learning Rate

# %%
tf.keras.backend.clear_session()

model = models.Sequential()

model.add(Dense(64, input_shape=(train_X.shape[1],)))

model.add(Activation('relu'))

model.add(Dense(64))
model.add(Activation('relu'))

model.add(Dense(1))

# %%
sgd = SGD(learning_rate=0.001)
model.compile(optimizer=sgd, loss='mse', metrics=['mse'])

# %%
# %%time

EPOCHS = 100

history = model.fit(
    train_X, 
    train_y,  # prepared data
    epochs=EPOCHS,
    validation_data=(test_X, test_y),
)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 1s 23ms/step - loss: 575.5075 - mse: 575.5075 - val_loss: 347.5268 - val_mse: 347.5268
# Epoch 2/100
# 9/9 [==============================] - 0s 5ms/step - loss: 295.4931 - mse: 295.4931 - val_loss: 67.8140 - val_mse: 67.8140
# Epoch 3/100
# 9/9 [==============================] - 0s 8ms/step - loss: 68.7459 - mse: 68.7459 - val_loss: 37.2827 - val_mse: 37.2827
# Epoch 4/100
# 9/9 [==============================] - 0s 9ms/step - loss: 34.4040 - mse: 34.4040 - val_loss: 25.8945 - val_mse: 25.8945
# Epoch 5/100
# 9/9 [==============================] - 0s 8ms/step - loss: 24.5378 - mse: 24.5378 - val_loss: 17.5375 - val_mse: 17.5375
# Epoch 6/100
# 9/9 [==============================] - 0s 6ms/step - loss: 20.4595 - mse: 20.4595 - val_loss: 19.9273 - val_mse: 19.9273
# Epoch 7/100
# 9/9 [==============================] - 0s 8ms/step - loss: 17.7218 - mse: 17.7218 - val_loss: 15.6638 - val_mse: 15.6638
# Epoch 8/100
# 9/9 [==============================] - 0s 8ms/step - loss: 16.5266 - mse: 16.5266 - val_loss: 14.2473 - val_mse: 14.2473
# Epoch 9/100
# Epoch 89/100
# 9/9 [==============================] - 0s 10ms/step - loss: 8.3516 - mse: 8.3516 - val_loss: 9.9698 - val_mse: 9.9698
# Epoch 90/100
# 9/9 [==============================] - 0s 11ms/step - loss: 7.7894 - mse: 7.7894 - val_loss: 9.8577 - val_mse: 9.8577
# Epoch 91/100
# 9/9 [==============================] - 0s 10ms/step - loss: 7.8519 - mse: 7.8519 - val_loss: 9.8995 - val_mse: 9.8995
# Epoch 92/100
# 9/9 [==============================] - 0s 8ms/step - loss: 7.7286 - mse: 7.7286 - val_loss: 10.7937 - val_mse: 10.7937
# Epoch 93/100
# 9/9 [==============================] - 0s 11ms/step - loss: 7.6289 - mse: 7.6289 - val_loss: 9.6129 - val_mse: 9.6129
# Epoch 94/100
# 9/9 [==============================] - 0s 11ms/step - loss: 7.7577 - mse: 7.7577 - val_loss: 8.5855 - val_mse: 8.5855
# Epoch 95/100
# 9/9 [==============================] - 0s 9ms/step - loss: 7.7685 - mse: 7.7685 - val_loss: 9.1813 - val_mse: 9.1813
# Epoch 96/100
# 9/9 [==============================] - 0s 11ms/step - loss: 7.5879 - mse: 7.5879 - val_loss: 9.0318 - val_mse: 9.0318
# Epoch 97/100
# 9/9 [==============================] - 0s 11ms/step - loss: 7.6331 - mse: 7.6331 - val_loss: 10.4860 - val_mse: 10.4860
# Epoch 98/100
# 9/9 [==============================] - 0s 10ms/step - loss: 7.5533 - mse: 7.5533 - val_loss: 9.5297 - val_mse: 9.5297
# Epoch 99/100
# 9/9 [==============================] - 0s 9ms/step - loss: 7.4769 - mse: 7.4769 - val_loss: 10.0090 - val_mse: 10.0090
# Epoch 100/100
# 9/9 [==============================] - 0s 11ms/step - loss: 7.5898 - mse: 7.5898 - val_loss: 10.4391 - val_mse: 10.4391
# CPU times: user 7.05 s, sys: 265 ms, total: 7.31 s
# Wall time: 8.26 s

# %%
plot_mse(history.history)
plot_loss(history.history)

# %% [markdown]
# ## Participant Exercise: 1
#
# 1. Change the activation functions to a) sigmoid and b) tanh and build the model
# 2. Add more neurons to the model
# 3. Add model layers to the model
#
# Print the model summary and validation loss from the last epoch.

# %% [markdown]
# ### Model Prediction and Measure Accuracy

# %%
pred_y = model.predict(test_X)
# Out:
# 3/3 [==============================] - 0s 3ms/step

# %%
np.sqrt(metrics.mean_squared_error( test_y, pred_y ))
# Out:
# 25.03010061330733

# %% [markdown]
# ## Using Callbacks

# %%
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

# %%
callbacks_list = [ReduceLROnPlateau(monitor='val_loss',
                                    factor=0.1, 
                                    patience=3),
                  EarlyStopping(monitor='val_loss',
                                patience=6),
                  ModelCheckpoint(filepath='boston_house_model.h5',
                                  save_format='tf',
                                  monitor='val_loss',
                                  save_best_only=True)]

# %%
tf.keras.backend.clear_session()

model = models.Sequential()

model.add(Dense(64, input_shape=(train_X.shape[1],)))

model.add(Activation('relu'))

model.add(Dense(64))
model.add(Activation('relu'))

model.add(Dense(1))

# %%
sgd = SGD(learning_rate=0.005)
model.compile(optimizer=sgd, loss='mse', metrics=['mse'])

# %%
# %%time

EPOCHS = 100

history = model.fit(
    train_X, 
    train_y,  # prepared data
    epochs=EPOCHS,
    callbacks = callbacks_list,
    validation_data=(test_X, test_y),
)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 1s 45ms/step - loss: 273.5806 - mse: 273.5806 - val_loss: 22.6068 - val_mse: 22.6068 - lr: 0.0050
# Epoch 2/100
# 9/9 [==============================] - 0s 13ms/step - loss: 66.2574 - mse: 66.2574 - val_loss: 110.4833 - val_mse: 110.4833 - lr: 0.0050
# Epoch 3/100
# 9/9 [==============================] - 0s 13ms/step - loss: 41.7340 - mse: 41.7340 - val_loss: 16.1345 - val_mse: 16.1345 - lr: 0.0050
# Epoch 4/100
# 9/9 [==============================] - 0s 13ms/step - loss: 30.1011 - mse: 30.1011 - val_loss: 14.7885 - val_mse: 14.7885 - lr: 0.0050
# Epoch 5/100
# 9/9 [==============================] - 0s 12ms/step - loss: 17.3305 - mse: 17.3305 - val_loss: 11.1439 - val_mse: 11.1439 - lr: 0.0050
# Epoch 6/100
# 9/9 [==============================] - 0s 11ms/step - loss: 15.3663 - mse: 15.3663 - val_loss: 68.3293 - val_mse: 68.3293 - lr: 0.0050
# Epoch 7/100
# 9/9 [==============================] - 0s 10ms/step - loss: 13.9912 - mse: 13.9912 - val_loss: 52.1078 - val_mse: 52.1078 - lr: 0.0050
# Epoch 8/100
# 9/9 [==============================] - 0s 9ms/step - loss: 18.5384 - mse: 18.5384 - val_loss: 50.1123 - val_mse: 50.1123 - lr: 0.0050
# Epoch 9/100
# 9/9 [==============================] - 0s 10ms/step - loss: 20.5137 - mse: 20.5137 - val_loss: 13.4090 - val_mse: 13.4090 - lr: 5.0000e-04
# Epoch 10/100
# 9/9 [==============================] - 0s 12ms/step - loss: 10.6981 - mse: 10.6981 - val_loss: 10.6767 - val_mse: 10.6767 - lr: 5.0000e-04
# Epoch 11/100
# 9/9 [==============================] - 0s 10ms/step - loss: 9.9195 - mse: 9.9195 - val_loss: 10.1626 - val_mse: 10.1626 - lr: 5.0000e-04
# Epoch 12/100
# 9/9 [==============================] - 0s 7ms/step - loss: 9.8021 - mse: 9.8021 - val_loss: 9.6873 - val_mse: 9.6873 - lr: 5.0000e-04
# Epoch 13/100
# 9/9 [==============================] - 0s 9ms/step - loss: 9.7276 - mse: 9.7276 - val_loss: 9.3712 - val_mse: 9.3712 - lr: 5.0000e-04
# Epoch 14/100
# 9/9 [==============================] - 0s 7ms/step - loss: 9.5588 - mse: 9.5588 - val_loss: 9.1450 - val_mse: 9.1450 - lr: 5.0000e-04
# Epoch 15/100
# 9/9 [==============================] - 0s 9ms/step - loss: 9.5547 - mse: 9.5547 - val_loss: 9.0550 - val_mse: 9.0550 - lr: 5.0000e-04
# Epoch 16/100
# 9/9 [==============================] - 0s 6ms/step - loss: 9.4578 - mse: 9.4578 - val_loss: 9.3790 - val_mse: 9.3790 - lr: 5.0000e-04
# Epoch 17/100
# 9/9 [==============================] - 0s 9ms/step - loss: 9.4592 - mse: 9.4592 - val_loss: 8.9407 - val_mse: 8.9407 - lr: 5.0000e-04
# Epoch 18/100
# 9/9 [==============================] - 0s 9ms/step - loss: 9.3949 - mse: 9.3949 - val_loss: 8.8516 - val_mse: 8.8516 - lr: 5.0000e-04
# Epoch 19/100
# 9/9 [==============================] - 0s 8ms/step - loss: 9.3440 - mse: 9.3440 - val_loss: 8.9054 - val_mse: 8.9054 - lr: 5.0000e-04
# Epoch 20/100
# 9/9 [==============================] - 0s 9ms/step - loss: 9.3248 - mse: 9.3248 - val_loss: 8.7398 - val_mse: 8.7398 - lr: 5.0000e-04
# Epoch 21/100
# 9/9 [==============================] - 0s 9ms/step - loss: 9.2339 - mse: 9.2339 - val_loss: 9.0544 - val_mse: 9.0544 - lr: 5.0000e-04
# Epoch 22/100
# 9/9 [==============================] - 0s 10ms/step - loss: 9.2411 - mse: 9.2411 - val_loss: 8.8824 - val_mse: 8.8824 - lr: 5.0000e-04
# Epoch 23/100
# 9/9 [==============================] - 0s 7ms/step - loss: 9.2030 - mse: 9.2030 - val_loss: 9.0298 - val_mse: 9.0298 - lr: 5.0000e-04
# Epoch 24/100
# 9/9 [==============================] - 0s 8ms/step - loss: 9.0224 - mse: 9.0224 - val_loss: 8.9870 - val_mse: 8.9870 - lr: 5.0000e-05
# Epoch 25/100
# 9/9 [==============================] - 0s 10ms/step - loss: 9.0159 - mse: 9.0159 - val_loss: 9.0448 - val_mse: 9.0448 - lr: 5.0000e-05
# Epoch 26/100
# 9/9 [==============================] - 0s 9ms/step - loss: 9.0127 - mse: 9.0127 - val_loss: 9.0066 - val_mse: 9.0066 - lr: 5.0000e-05
# CPU times: user 2.82 s, sys: 100 ms, total: 2.92 s
# Wall time: 3.29 s

# %%
plot_mse(history.history)
plot_loss(history.history)

# %%
# !ls -al
# Out:
# total 64
# drwxr-xr-x 1 root root  4096 Apr 26 07:33 .
# drwxr-xr-x 1 root root  4096 Apr 26 07:27 ..
# -rw-r--r-- 1 root root 41888 Apr 26 07:33 boston_house_model.h5
# drwxr-xr-x 4 root root  4096 Apr 24 17:04 .config
# drwx------ 6 root root  4096 Apr 26 07:29 drive
# drwxr-xr-x 1 root root  4096 Apr 24 17:05 sample_data

# %% [markdown]
# ## Loading Model and Making Prediction

# %%
new_model = keras.models.load_model('boston_house_model.h5')

# %%
test_X[0:1]
# Out:
# array([[ 4.80621507, -0.48905255,  1.0414365 , -0.22667907,  1.15180046,
#         -0.07900787,  0.4179894 , -0.9522334 ,  1.73169626,  1.58445097,
#          0.82518641, -4.32771609,  0.32186524]])

# %%
house_price_pred = model.predict(test_X[0:1])
# Out:
# 1/1 [==============================] - 0s 23ms/step

# %%
house_price_pred[0]
# Out:
# array([12.386493], dtype=float32)

# %% [markdown]
# The new data always need to be normalized with training data parameters (mean and standard deviation).
